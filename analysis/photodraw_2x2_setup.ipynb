# %% [markdown]
# ### Import packages and set up paths

# %%
import os
import sys
import json
import utils
import socket
import base64
import importlib
import numpy as np
import pandas as pd
import pymongo as pm
from PIL import Image
from io import BytesIO
from scipy import stats

from sklearn.model_selection import KFold
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedKFold

import seaborn as sns
import matplotlib.pyplot as plt

# %%
# directory & file hierarchy
proj_dir = os.path.abspath('..')
analysis_dir = os.getcwd()
results_dir = os.path.join(proj_dir,'results')
csv_dir = os.path.join(results_dir,'csv')
sketch_dir = os.path.abspath(os.path.join(proj_dir,'sketches'))
gallery_dir = os.path.abspath(os.path.join(proj_dir,'gallery'))
if socket.gethostname() == 'nightingale':
    feature_dir = os.path.abspath('/mnt/pentagon/photodraw/features/')
else:
    feature_dir = os.path.abspath(os.path.join(proj_dir,'features'))
    
## add helpers to python path
if os.path.join(proj_dir,'utils') not in sys.path:
    sys.path.append(os.path.join(proj_dir,'utils'))   

def make_dir_if_not_exists(dir_name):   
    if not os.path.exists(dir_name):
        os.makedirs(dir_name)
    return dir_name

## create directories that don't already exist        
result = [make_dir_if_not_exists(x) for x in [results_dir,csv_dir,sketch_dir,gallery_dir,feature_dir]]

# %%
def get_coll_from_mongo(coll_name, iter_name, auth, reallyRun = False):
    if reallyRun:
        # set vars 
        pswd = auth.values[0][0]
        user = 'sketchloop'
        host = 'cogtoolslab.org'

        # have to fix this to be able to analyze from local
        import socket
        if socket.gethostname().split('_')[0]=='Justin':
            conn = pm.MongoClient('mongodb://sketchloop:' + pswd + '@127.0.0.1:27020')
        else:
            conn = pm.MongoClient('mongodb://sketchloop:' + pswd + '@127.0.0.1:27017')
        db = conn['photodraw']
        coll = db[coll_name]

        ## how many records do we have in mongo?
        print(f'We have {coll.estimated_document_count()} records in {coll_name}: {iter_name}.')
        
        # commenting out because it's really slow
        print('{} of these are sketches.'.format(len(list(coll.find({'iterationName':iter_name, 'eventType':'sketch'})))))
        print('{} of these are strokes.'.format(len(list(coll.find({'iterationName':iter_name, 'eventType':'stroke'})))))
        print('{} of these are surveys.'.format(len(list(coll.find({'iterationName':iter_name, 'eventType':'survey'})))))
        
        # Sketches
        k = coll.find({'iterationName':iter_name, 'eventType':'sketch'})
        K = pd.DataFrame(k)

        # Strokes
        t = coll.find({'iterationName':iter_name, 'eventType':'stroke'})
        T = pd.DataFrame(t)

        # Surveys
        s = coll.find({'iterationName':iter_name, 'eventType':'survey'})
        S = pd.DataFrame(s) #.sort_values('aID').reset_index(drop=True)
    return K, T, S

def subset_valid_drawings(data):
    unique_cats = pd.DataFrame(data.groupby(['prolificID', 'gameID']).category.nunique()).reset_index()
    complete_sessions = unique_cats[unique_cats.category == 32].gameID
    return data[data.gameID.isin(complete_sessions)]

# method to flag outlier data
def flag_outliers(data, varList, sd = 3):
    return (np.abs(stats.zscore(data[varList])) > sd).any(axis=1)

# %%
def compute_class_predictions(data, labels):
    # setup cross validation framework
    kFold = StratifiedKFold(n_splits = 5, shuffle = True, random_state = 0)
    logit = LogisticRegression(max_iter=1000)

    prob_dict = {}
    pred_dict = {} # get it?
    for train_ind, test_ind in kFold.split(data, labels):
        # fit logistic regression and make indices corresponding to each of the model classes
        model = logit.fit(data[train_ind], labels[train_ind])
        class_inds = {label : ind for ind, label in enumerate(model.classes_)}

        # predict model probabilities and get find true class prediction probability
        probarrs = model.predict_proba(data[test_ind])
        label_inds = np.asarray([class_inds[label] for label in labels[test_ind]])[:, None]
        prob_of_classification = np.take_along_axis(probarrs, label_inds, axis=1).reshape((-1,))

        # update dictionaries with probabilities and predictions
        prob_dict.update(list(zip(test_ind, prob_of_classification)))
        pred_dict.update(list(zip(test_ind, model.predict(data[test_ind]) == labels[test_ind])))

    # ensure we are actually getting probabilities
    assert all(np.fromiter(prob_dict.values(), dtype = float) <= 1)
    assert all(np.fromiter(prob_dict.values(), dtype = float) >= 0)
    
    return prob_dict, pred_dict 

# convert raw png data to greyscale image array
def image_to_array(imgdata, imgsize = (224, 224)):
    imgarray = np.asarray(Image.open(BytesIO(base64.b64decode(imgdata))).resize(imgsize))
    return 255 - imgarray[:,:,3] 

def to_rgb(im):
    # suprisingly fast
    w, h = im.shape
    ret = np.empty((w, h, 3), dtype=np.uint8)
    ret[:, :, 0] = im
    ret[:, :, 1] = im
    ret[:, :, 2] = im
    return ret

# %%
def setup_dataframes(sketch_data, stroke_data, survey_data, experiment_type):

    # subset the sessions that were complete (all 32 trials done)
    sketch_data = subset_valid_drawings(sketch_data)
    stroke_data = subset_valid_drawings(stroke_data)

    # then sort the trial values comparably
    sketch_data = sketch_data.sort_values(by=['gameID', 'category']).reset_index(drop=True)
    stroke_data = stroke_data.sort_values(by=['gameID', 'category']).reset_index(drop=True)
    survey_data = survey_data.sort_values(by=['gameID']).reset_index(drop=True)

    # count the number of unique categories in each prolific-gameID combo
    id_counts = pd.DataFrame(sketch_data.groupby(['prolificID','gameID']).category.nunique()).reset_index()
    # get the gameIDs corresponding only to complete sessions 
    valid_gameIDs = id_counts[id_counts.category == 32].drop_duplicates('prolificID', 'last').gameID.values

    # subset valid sessions
    sketch_data = sketch_data[sketch_data.gameID.isin(valid_gameIDs)]
    stroke_data = stroke_data[stroke_data.gameID.isin(valid_gameIDs)]
    survey_data = survey_data[survey_data.gameID.isin(valid_gameIDs)]

    # ensure that there are 32 completed trials for each session subsetted
    assert all(sketch_data.groupby('gameID').trialNum.nunique() == 32)
    assert all(stroke_data.groupby('gameID').trialNum.nunique() == 32)
    assert all(sketch_data.groupby('gameID').category.nunique() == 32)
    assert all(stroke_data.groupby('gameID').category.nunique() == 32)

    assert all(sketch_data.groupby('prolificID').trialNum.nunique() == 32)
    assert all(stroke_data.groupby('prolificID').trialNum.nunique() == 32)
    assert all(sketch_data.groupby('prolificID').category.nunique() == 32)
    assert all(stroke_data.groupby('prolificID').category.nunique() == 32)

    # ensure that the the number of sketches is divisible by the number of trials in a session
    assert len(sketch_data) % 32 == 0 
    print(f'After subsetting valid sessions, there are {len(sketch_data)} valid sketches' +
                                                f' and {len(stroke_data)} valid strokes.')
    # reset index once more
    sketch_data = sketch_data.sort_values(by=['gameID', 'category']).reset_index(drop=True)
    stroke_data = stroke_data.sort_values(by=['gameID', 'category']).reset_index(drop=True)
    survey_data = survey_data.sort_values(by=['gameID']).reset_index(drop=True)
    
    # add time spent actively drawing (e.g. mouse click down) per sketch to sketch dataframe
    activeSketchTime = stroke_data.groupby(['gameID', 'category'])[
        ['startStrokeTime', 'endStrokeTime']].apply(lambda x: sum(x.endStrokeTime - x.startStrokeTime))
    sketch_data['activeSketchTime'] = sketch_data.set_index(['gameID', 'category']).index.map(activeSketchTime.to_dict())

    # add total ink spend on each drawing, computed by the sum of each stroke's arc length
    totalInk = stroke_data.groupby(['gameID', 'category'])['arcLength'].agg(np.sum)
    sketch_data['totalInk'] = sketch_data.set_index(['gameID', 'category']).index.map(totalInk.to_dict())

    # flag data marked as outliers according to specified variables
    sketch_data['isOutlier'] = flag_outliers(sketch_data, ['numStrokes', 'activeSketchTime', 'totalInk'], sd = 3)

    # transform raw png images into flattened (num sessions*32 , 224*224) numpy array
    img_data = np.asarray([image_to_array(data).flatten() for data in sketch_data.pngData])
    img_labels = np.asarray(sketch_data.category)
    img_data_tosave = img_data
    
    # apply min-max scalar on features 
    img_data = img_data - img_data.mean(axis = 0) 

    # ensure data and labels match up in length
    assert img_data.shape[0] == img_labels.shape[0]

    # add logistic regression predictions and probabilities to sketch dataframe
    prob_dict, pred_dict = compute_class_predictions(img_data, img_labels)
    sketch_data['prob_true_predict'] = sketch_data.index.map(prob_dict)
    sketch_data['true_predict'] = sketch_data.index.map(pred_dict)
    
    # replace imageURL nans with 'text' in the text condition, and clean up to just contain 
    if all(sketch_data.condition == 'text'):
        sketch_data['imageURL'] = sketch_data.imageURL.fillna('text')
    else:
        sketch_data['imageURL'] = sketch_data.imageURL.str.split('/', expand=True).iloc[:, -1]\
                                                      .str.split('_', 2, expand=True).iloc[:,:2]\
                                                      .agg('_'.join, axis=1)
    
    # convert the sketch data to RGB format
    img_data_tosave = img_data_tosave.reshape((len(img_data_tosave), 224, 224))
    img_data_tosave = np.asarray([to_rgb(img) for img in img_data_tosave])
    
    # add in survey data to sketch data
    surveys = []
    for gid in survey_data.gameID.unique():
        resp = survey_data[survey_data.gameID == gid]['responses'].values
        dictresp = [json.loads(response) for response in resp]
        dictresp = {k: v for d in dictresp for k, v in d.items()}
        dictresp['gameID'] =  gid
        surveys.append(dictresp)
    surveys = pd.DataFrame(surveys).set_index('gameID')
    surveys = surveys.reindex(sorted(surveys.columns), axis=1)
    sketch_data[['TechnicalDifficultiesFreeResp','inputDevice',
       'participantAge','participantComments',
       'participantSex', 'subjectiveSkill']] = sketch_data.apply(lambda x: surveys.loc[x.gameID], axis = 1)
    
    # add experiment into dataframes
    sketch_data['experiment'] = experiment_type
    stroke_data['experiment'] = experiment_type
    survey_data['experiment'] = experiment_type
    
    # add goal into dataframes
    sketch_data['goal'] = experiment_type.split('-')[0]
    stroke_data['goal'] = experiment_type.split('-')[0]
    survey_data['goal'] = experiment_type.split('-')[0]
    
    # add null batch_num column in text conditions
    if 'batch_num' not in sketch_data.columns:
        sketch_data['batch_num'] = np.nan
        stroke_data['batch_num'] = np.nan
        survey_data['batch_num'] = np.nan
    
    # finally, drop participant identifier now that gameID is equivalent
    sketch_data = sketch_data.drop(columns='prolificID')
    stroke_data = stroke_data.drop(columns='prolificID')
    survey_data = survey_data.drop(columns='prolificID')
    
    return sketch_data, stroke_data, survey_data, img_data_tosave

# %% [markdown]
# ### establish connection to mongo
#
# `ssh -fNL 27020:127.0.0.1:27017 jyang@cogtoolslab.org`
# `ssh -fNL 27017:127.0.0.1:27017 jyang@cogtoolslab.org`

# %%
# %%time 
sketch_data, stroke_data, survey_data = [], [], []
for experiment in ['categorydraw-text', 'instancedraw-text', 'categorydraw-photo', 'instancedraw-photo']: 
    # this auth.txt file contains the password for the sketchloop user
    auth = pd.read_csv(os.path.join(analysis_dir,'auth.txt'), header = None) 

    # get raw experiment data from mongo
    sketch, stroke, survey = get_coll_from_mongo(experiment, 'run0', auth = auth, reallyRun = True)

    # set up dataframes for analysis, get raw image arrays
    sketch, stroke, survey, im_data = setup_dataframes(sketch, stroke, survey, experiment)
    sketch_data.append(sketch)
    stroke_data.append(stroke)
    survey_data.append(survey)    
    
    # save image data 
    np.save(os.path.abspath(os.path.join(feature_dir, f'{experiment}_flattened_pixels.npy')), im_data)
    
    print(f'Saved out {experiment} data. Path names are:')
    print(os.path.abspath(os.path.join(feature_dir, f'{experiment}_flattened_pixels.npy')))

print('\n')    

sketch_data = pd.concat(sketch_data)
stroke_data = pd.concat(stroke_data)
survey_data = pd.concat(survey_data)

reallyRun = False
if reallyRun:

    # save data out to csv
    sketch_data.to_csv(os.path.join(csv_dir, 'photodraw2x2_sketch_data.csv'), index = False)
    stroke_data.to_csv(os.path.join(csv_dir, 'photodraw2x2_stroke_data.csv'), index = False)
    survey_data.to_csv(os.path.join(csv_dir, 'photodraw2x2_survey_data.csv'), index = False)

    print(os.path.join(csv_dir, f'photodraw2x2_sketch_data.csv'))
    print(os.path.join(csv_dir, f'photodraw2x2_stroke_data.csv'))
    print(os.path.join(csv_dir, f'photodraw2x2_survey_data.csv'))
# Out:
# We have 34631 records in categorydraw-text: run0.
# After subsetting valid sessions, there are 3072 valid sketches and 27435 valid strokes.
# Saved out categorydraw-text data. Path names are:
# F:\photodraw\features\categorydraw-text_flattened_pixels.npy
# We have 51876 records in instancedraw-text: run0.
# After subsetting valid sessions, there are 3072 valid sketches and 39345 valid strokes.
# Saved out instancedraw-text data. Path names are:
# F:\photodraw\features\instancedraw-text_flattened_pixels.npy
# We have 39310 records in categorydraw-photo: run0.
# After subsetting valid sessions, there are 3072 valid sketches and 32949 valid strokes.
# Saved out categorydraw-photo data. Path names are:
# F:\photodraw\features\categorydraw-photo_flattened_pixels.npy
# We have 51312 records in instancedraw-photo: run0.
# After subsetting valid sessions, there are 3072 valid sketches and 44082 valid strokes.
# Saved out instancedraw-photo data. Path names are:
# F:\photodraw\features\instancedraw-photo_flattened_pixels.npy
#
#
# F:\photodraw\results\csv\photodraw2x2_sketch_data.csv
# F:\photodraw\results\csv\photodraw2x2_stroke_data.csv
# F:\photodraw\results\csv\photodraw2x2_survey_data.csv
# Wall time: 20min 29s

# %% [markdown]
# ### render out sketches for inspection

# %%
sketch_df = pd.read_csv(os.path.join(csv_dir, 'photodraw2x2_sketch_data.csv'))
for experiment in ['categorydraw-text', 'instancedraw-text', 'categorydraw-photo', 'instancedraw-photo']:   
    sketch_experiment_df = sketch_df[sketch_df.experiment == experiment]
    importlib.reload(utils)
    
    print(f'Rendering {experiment} sketch data...')
    utils.render_images(sketch_experiment_df, data = 'pngData',
                        metadata = ['gameID', 'trialNum', 'condition','category','imageURL', 'goal'],
                        out_dir = os.path.join(sketch_dir, experiment))
# Out:
# Done rendering 3072 images to F:\photodraw\sketches\instancedraw-photo.

# %% [markdown]
# ### Make sketch galleries

# %%
for experiment in ['categorydraw-text', 'instancedraw-text', 'categorydraw-photo', 'instancedraw-photo']:
    
    gallery_path = make_dir_if_not_exists(os.path.join(gallery_dir, experiment))
    sketch_paths = sorted([sketch_path for sketch_path in os.listdir(os.path.join(sketch_dir, experiment))])
    gameids = list(np.unique([i.split('_')[0] for i in sketch_paths]))

    if (len(os.listdir(gallery_path))==0):
        ## generate gallery for each participant
        for gind, game in enumerate(gameids): 
            print('Generating sketch gallery for participant: {} | {} of {}'.format(game,gind+1,len(gameids)))
            # get list of all sketch paths JUST from current game
            game_sketch_paths = [path for path in sketch_paths if path.split('_')[0] == game]
            game_sketch_paths = sorted(game_sketch_paths, key = lambda x: x.split('_')[3].split('.')[0]) 
            fig = plt.figure(figsize=(12,20))   
            for i,f in enumerate(game_sketch_paths):
                # open image
                im = Image.open(os.path.join(sketch_dir, experiment, f))
                # get metadata
                gameid = f.split('_')[0] 
                trialNum = f.split('_')[1]
                condition = f.split('_')[2]
                category = f.split('_')[3].split('.')[0]   
                # make gallery
                p = plt.subplot(8,4,i+1)
                plt.imshow(im)
                sns.set_style('white')
                k = p.get_xaxis().set_ticklabels([])
                k = p.get_yaxis().set_ticklabels([])
                k = p.get_xaxis().set_ticks([])
                k = p.get_yaxis().set_ticks([])   
                p.axis('off')
                plt.title('{} {} {}'.format(trialNum,condition,category))
            plt.suptitle(gameid)
            fname = '{}.png'.format(gameid)
            plt.savefig(os.path.join(gallery_path,fname))
            plt.close(fig)
        print('Done!')

# %%
for experiment in ['categorydraw-text', 'instancedraw-text', 'categorydraw-photo', 'instancedraw-photo']:
    
    gallery_path = make_dir_if_not_exists(os.path.join(gallery_dir, experiment))
    sketch_paths = sorted([sketch_path for sketch_path in os.listdir(os.path.join(sketch_dir, experiment))])
    gameids = list(np.unique([i.split('_')[0] for i in sketch_paths]))

    if (len(os.listdir(gallery_path))==0):
        ## generate gallery for each participant
        for gind, game in enumerate(gameids): 
            print('Generating sketch gallery for participant: {} | {} of {}'.format(game,gind+1,len(gameids)))
            # get list of all sketch paths JUST from current game
            game_sketch_paths = [path for path in sketch_paths if path.split('_')[0] == game]
            game_sketch_paths = sorted(game_sketch_paths, key = lambda x: x.split('_')[3].split('.')[0]) 
            fig = plt.figure(figsize=(12,20))   
            for i,f in enumerate(game_sketch_paths):
                # open image
                im = Image.open(os.path.join(sketch_dir, experiment, f))
                # get metadata
                gameid = f.split('_')[0] 
                trialNum = f.split('_')[1]
                condition = f.split('_')[2]
                category = f.split('_')[3].split('.')[0]   
                # make gallery
                p = plt.subplot(8,4,i+1)
                plt.imshow(im)
                sns.set_style('white')
                k = p.get_xaxis().set_ticklabels([])
                k = p.get_yaxis().set_ticklabels([])
                k = p.get_xaxis().set_ticks([])
                k = p.get_yaxis().set_ticks([])   
                p.axis('off')
                plt.title('{} {} {}'.format(trialNum,condition,category))
            plt.suptitle(gameid)
            fname = '{}.png'.format(gameid)
            plt.savefig(os.path.join(gallery_path,fname))
            plt.close(fig)
        print('Done!')
# Out:
# Generating sketch gallery for participant: 0058-ce87d784-26a0-4ee6-b31e-04b7669d6ffa | 1 of 96
# Generating sketch gallery for participant: 0072-4fb13d34-250e-4a72-80f9-bd57bffddfce | 2 of 96
# Generating sketch gallery for participant: 0597-1cebe818-5134-457d-a6ae-882fa273e7ae | 3 of 96
# Generating sketch gallery for participant: 0712-06cd00bd-1a04-4d87-9315-2e286faecc61 | 4 of 96
# Generating sketch gallery for participant: 0986-ad780b37-aac4-417d-a20b-997204e9a3f2 | 5 of 96
# Generating sketch gallery for participant: 1235-00cbba14-ad50-482e-be5c-f62e550eabc2 | 6 of 96
# Generating sketch gallery for participant: 1239-70860003-a9f6-40d6-bd05-df9e70196840 | 7 of 96
# Generating sketch gallery for participant: 1464-3f3ab669-fd0f-448e-abad-dc3b7364927d | 8 of 96
# Generating sketch gallery for participant: 1543-8902a2f3-2a2b-47fb-a7a8-37aa7a8e01cf | 9 of 96
# Generating sketch gallery for participant: 1613-b960b761-c83f-4cc7-8b13-29898c1d39fc | 10 of 96
# Generating sketch gallery for participant: 1745-178c806e-e3e0-4837-8888-ed92b266065d | 11 of 96
# Generating sketch gallery for participant: 1821-92d141c8-8ebc-4162-9946-e15ff7dd1fd0 | 12 of 96
# Generating sketch gallery for participant: 1991-e5d29e3a-ecd5-40db-9ca5-16a9b4d39fc7 | 13 of 96
# Generating sketch gallery for participant: 1995-b008f20d-b3ea-40e0-a451-aa4180157148 | 14 of 96
# Generating sketch gallery for participant: 2012-f4694a97-65e0-4049-bdec-ee8a9f1bd78b | 15 of 96
# Generating sketch gallery for participant: 2020-f4bccf2e-e678-4b7f-8fd6-c1ba1267d60e | 16 of 96
# Generating sketch gallery for participant: 2129-715c1183-c98d-4412-89d2-c88387fd7e60 | 17 of 96
# Generating sketch gallery for participant: 2154-892e9dc1-7a14-4030-9689-9c73ceaeef85 | 18 of 96
# Generating sketch gallery for participant: 2171-79c8ea6f-4c0c-4504-b09a-1a5477f63250 | 19 of 96
# Generating sketch gallery for participant: 2259-7d2104bb-39a8-4a99-b796-9e95b18a7789 | 20 of 96
# Generating sketch gallery for participant: 2384-a25b9d1b-7817-4779-a778-7ac9a6b3bc40 | 21 of 96
# Generating sketch gallery for participant: 2415-2d6522a8-5b9f-459b-af52-79594727fc8d | 22 of 96
# Generating sketch gallery for participant: 2460-15589d0f-8557-4eeb-b912-7134c174bded | 23 of 96
# Generating sketch gallery for participant: 2481-5c663e63-b7bd-45dd-b95e-cded63dab212 | 24 of 96
# Generating sketch gallery for participant: 2496-035a6bff-0951-47df-9ba8-5e320fcf511d | 25 of 96
# Generating sketch gallery for participant: 2693-441be756-a398-49a1-b016-6b88f1a0ba4c | 26 of 96
# Generating sketch gallery for participant: 2712-5ec352c8-40bd-467f-a116-cfbd912c55b9 | 27 of 96
# Generating sketch gallery for participant: 2730-0988580d-d610-4517-ab6b-87f11c1fc643 | 28 of 96
# Generating sketch gallery for participant: 2779-5111b9a4-4c89-4376-98f5-f7d434866a7d | 29 of 96
# Generating sketch gallery for participant: 2823-bfe9eab4-52de-48f5-9b52-b0281aaa7c28 | 30 of 96
# Generating sketch gallery for participant: 2974-e1bb24a2-44db-4755-ab1e-7f83ffdf7da5 | 31 of 96
# Generating sketch gallery for participant: 3267-389ba8f7-00a4-4f2b-98e8-ff6b30cd46e0 | 32 of 96
# Generating sketch gallery for participant: 3383-9cdb4123-e897-412b-a161-c47ae3f8b399 | 33 of 96
# Generating sketch gallery for participant: 3537-9ed5b960-4677-4967-a463-14a28133386e | 34 of 96
# Generating sketch gallery for participant: 3990-526bf01a-b17d-4286-9f83-353dfcde5ab6 | 35 of 96
# Generating sketch gallery for participant: 4051-016ead6a-a44a-4e75-9a13-fd55bf40750a | 36 of 96
# Generating sketch gallery for participant: 4128-9311cc3b-bc91-4a14-86f3-243fb39887f0 | 37 of 96
# Generating sketch gallery for participant: 4186-26dabd48-c7b8-4db7-863d-e824af234f80 | 38 of 96
# Generating sketch gallery for participant: 4205-410ad1f4-ed5d-4888-8933-ca9ec70f3525 | 39 of 96
# Generating sketch gallery for participant: 4313-57ff5820-268e-448d-a5ff-78536fba40c8 | 40 of 96
# Generating sketch gallery for participant: 4336-08c3721d-0e8a-4f1d-8662-4c2435ab3eb8 | 41 of 96
# Generating sketch gallery for participant: 4360-345a57d7-e7c6-4f53-af8e-62ab82a67259 | 42 of 96
# Generating sketch gallery for participant: 4363-e0c79ea1-01ba-4226-89e9-8e1d0127c420 | 43 of 96
# Generating sketch gallery for participant: 4635-556fe86a-51ea-4e9d-b88e-847b06bddd24 | 44 of 96
# Generating sketch gallery for participant: 4647-01daeb5c-344f-4f31-87fc-957873cd2f6b | 45 of 96
# Generating sketch gallery for participant: 4668-7d9fafb3-e6f1-4041-9909-a9184cfed76c | 46 of 96
# Generating sketch gallery for participant: 4727-8ab625f6-603c-4405-a1cc-815bdeaaa73c | 47 of 96
# Generating sketch gallery for participant: 4877-2c2c7e77-a172-409e-9972-e9b37d8894f6 | 48 of 96
# Generating sketch gallery for participant: 4918-d1d03160-f316-4f2c-adaa-54130d5b9282 | 49 of 96
# Generating sketch gallery for participant: 5205-c3089180-cc25-4439-ac8a-b1e1149e6b9a | 50 of 96
# Generating sketch gallery for participant: 5214-72573d5d-550c-4425-9a15-a64737545586 | 51 of 96
# Generating sketch gallery for participant: 5323-9bf5f70d-1499-4856-8e9e-3c1893868091 | 52 of 96
# Generating sketch gallery for participant: 5334-fad74275-d4eb-479e-8789-d11ac1198b68 | 53 of 96
# Generating sketch gallery for participant: 5346-ae1a476f-9fb9-428f-9eba-440c12933f66 | 54 of 96
# Generating sketch gallery for participant: 5415-2fd034ec-d2b3-455d-9d24-269ee45b9c7a | 55 of 96
# Generating sketch gallery for participant: 5454-cc2a95a0-1b72-4382-801d-4ca849d2565c | 56 of 96
# Generating sketch gallery for participant: 5493-c9b1bf66-0338-4c54-8838-94b545d62b14 | 57 of 96
# Generating sketch gallery for participant: 5515-d5e9e6e2-cc8c-488e-a189-3c25b2fe849e | 58 of 96
# Generating sketch gallery for participant: 5748-839e2490-c021-4e77-aef4-af11b4dc0ce1 | 59 of 96
# Generating sketch gallery for participant: 5855-72f5973a-483b-4868-983d-e81fbdb810c5 | 60 of 96
# Generating sketch gallery for participant: 6142-be369d4d-7805-45c2-a0a5-1d77ee1de986 | 61 of 96
# Generating sketch gallery for participant: 6423-47384530-d997-4bd2-aeb2-922f2e9ce0ce | 62 of 96
# Generating sketch gallery for participant: 6447-5b309444-c26f-4e90-ac81-77b6b23a3f47 | 63 of 96
# Generating sketch gallery for participant: 6562-1465e67d-cbd4-4642-b03d-6c37bb7e2496 | 64 of 96
# Generating sketch gallery for participant: 6569-ff52d9fc-1f2c-47ed-bd01-3d56b2b53c53 | 65 of 96
# Generating sketch gallery for participant: 6873-5585f19c-0c0c-48d2-a666-b1a438834176 | 66 of 96
# Generating sketch gallery for participant: 7007-8b5b255f-7664-47bb-a0bc-a4325aecf433 | 67 of 96
# Generating sketch gallery for participant: 7080-a277e396-2455-48b2-9635-6c22ec97204b | 68 of 96
# Generating sketch gallery for participant: 7119-2705e9da-b2db-4383-abd8-1f5816f55479 | 69 of 96
# Generating sketch gallery for participant: 7148-76ee94ab-de7c-4cae-ab2d-6b208525c111 | 70 of 96
# Generating sketch gallery for participant: 7244-55b63cd6-9df2-4f82-b0ac-dc8710fd6d3a | 71 of 96
# Generating sketch gallery for participant: 7314-21e096ef-5825-42b2-8e31-59f7dba04849 | 72 of 96
# Generating sketch gallery for participant: 7717-4f273190-6055-4410-9937-5197a759856f | 73 of 96
# Generating sketch gallery for participant: 7778-a8108fda-133c-44b2-8ef3-93e26d3c6ee8 | 74 of 96
# Generating sketch gallery for participant: 7825-68fbde64-e660-46f8-aa01-2e1aa2fbf7e3 | 75 of 96
# Generating sketch gallery for participant: 7883-cbe96198-c4b9-41df-b448-8d0073f1f7cc | 76 of 96
# Generating sketch gallery for participant: 7901-f1e3059f-d611-48cb-a338-0a3ce8b92f16 | 77 of 96
# Generating sketch gallery for participant: 7904-2f192d1d-ce3c-499c-bbd5-91d99e6efadf | 78 of 96
# Generating sketch gallery for participant: 7999-71401102-24d1-4dd9-bc4d-5eea2d117522 | 79 of 96
# Generating sketch gallery for participant: 8001-6d504e8f-92ca-4d72-bdf6-a9285cb8cf6d | 80 of 96
# Generating sketch gallery for participant: 8022-00512c0f-fc08-4e40-b56e-367102fcee97 | 81 of 96
# Generating sketch gallery for participant: 8217-d13d91f3-c8a4-404c-b4b6-6226a18d8f5b | 82 of 96
# Generating sketch gallery for participant: 8302-5674e168-d973-4229-91a0-7f8b9e34d6e2 | 83 of 96
# Generating sketch gallery for participant: 8332-42d38352-f283-40da-86d5-1a259d8e58ee | 84 of 96
# Generating sketch gallery for participant: 8514-c0eda6d3-431a-44d8-b7ce-0dd849214d35 | 85 of 96
# Generating sketch gallery for participant: 8597-1aed5e8c-946e-4d4f-ba6f-c141a6cf1ee0 | 86 of 96
# Generating sketch gallery for participant: 8603-55797fab-2893-4f7d-b644-af54210aac46 | 87 of 96
# Generating sketch gallery for participant: 8803-1dffbfb2-96e0-4397-b4c8-56172d178a0e | 88 of 96
# Generating sketch gallery for participant: 8835-fe725b87-5dd0-469f-8da2-0980223552ec | 89 of 96
# Generating sketch gallery for participant: 9016-0c32b658-ab9b-46a1-9c8b-230a85373ee3 | 90 of 96
# Generating sketch gallery for participant: 9054-7a3cd65e-55bf-4f03-a3d5-cbff651f2dd7 | 91 of 96
# Generating sketch gallery for participant: 9068-867eea6d-0335-413c-b112-beb12c1018ae | 92 of 96
# Generating sketch gallery for participant: 9229-3da49b43-d59a-4b84-b777-90339bbb77cd | 93 of 96
# Generating sketch gallery for participant: 9526-09266e5f-629d-4604-b73a-47c448e4a5d0 | 94 of 96
# Generating sketch gallery for participant: 9834-c61a287a-0706-46e9-a100-416413cbcc57 | 95 of 96
# Generating sketch gallery for participant: 9850-f33717b7-3f0c-4aa8-9a84-919b086a10ce | 96 of 96
# Done!
# Generating sketch gallery for participant: 0132-16d51fc4-5ff8-466b-bbb9-fa3666c4418a | 1 of 96
# Generating sketch gallery for participant: 0142-23e07274-3b42-41d1-8a69-1db52f59b033 | 2 of 96
# Generating sketch gallery for participant: 0288-58ffcddb-7089-48e4-bfae-c176b105fb08 | 3 of 96
# Generating sketch gallery for participant: 0364-09fd08c6-66f8-4f53-9e3e-fc25dd200f3b | 4 of 96
# Generating sketch gallery for participant: 0851-92ceefe8-d7a7-4012-bda1-a95f60a1b860 | 5 of 96
# Generating sketch gallery for participant: 0963-4beb1672-4543-4fda-aeea-7ddcbcd0dbc1 | 6 of 96
# Generating sketch gallery for participant: 1320-74d60967-0661-4bff-8977-4d286dae4174 | 7 of 96
# Generating sketch gallery for participant: 1354-80d0313c-9522-4aeb-9569-71db80ab253a | 8 of 96
# Generating sketch gallery for participant: 1359-c79b347b-66bc-43b4-9183-29fe543af2b9 | 9 of 96
# Generating sketch gallery for participant: 1471-13e231d3-442b-4163-bab4-48b048d4e815 | 10 of 96
# Generating sketch gallery for participant: 1495-c7ea9226-8b84-43ca-b191-9ea0a09ceb80 | 11 of 96
# Generating sketch gallery for participant: 1701-960cf063-7cda-45d8-8806-b5aff6fce6e7 | 12 of 96
# Generating sketch gallery for participant: 1736-01a627cb-29c0-42e2-8be0-200c02b2c7f6 | 13 of 96
# Generating sketch gallery for participant: 1743-df30b302-c801-458d-9206-6b546226fb9e | 14 of 96
# Generating sketch gallery for participant: 1848-e8f260eb-e050-41cd-b370-3410c3abe229 | 15 of 96
# Generating sketch gallery for participant: 1894-8dcb9a0a-f106-41b4-852f-1692b0737001 | 16 of 96
# Generating sketch gallery for participant: 1999-ecdcf7a9-f504-4368-bbc6-c15356591b4f | 17 of 96
# Generating sketch gallery for participant: 2045-83c70ce4-86bf-4da9-acae-4ac27fe2b5e9 | 18 of 96
# Generating sketch gallery for participant: 2529-2a20c7d7-fa1f-464e-acb5-54b86f49f112 | 19 of 96
# Generating sketch gallery for participant: 2736-3c8a94b8-bda1-4dcf-8525-7c7d67e0f7ed | 20 of 96
# Generating sketch gallery for participant: 2762-644fecdc-29f3-48fa-8ec0-f076794da463 | 21 of 96
# Generating sketch gallery for participant: 2772-49fbe1c4-3586-4023-8ad3-c08cd4f895e4 | 22 of 96
# Generating sketch gallery for participant: 2799-a2e3e531-2af7-486f-8f98-6a64407c6992 | 23 of 96
# Generating sketch gallery for participant: 2878-df568025-aa4a-4529-9f50-a70b2fc9e542 | 24 of 96
# Generating sketch gallery for participant: 2887-ecd3d3c9-4b72-46e6-bd80-32fb3c987e69 | 25 of 96
# Generating sketch gallery for participant: 2896-cc0d57fc-6c28-4393-b351-d345bb961918 | 26 of 96
# Generating sketch gallery for participant: 2898-320ed5a5-d353-4efa-808e-375c572246e4 | 27 of 96
# Generating sketch gallery for participant: 2903-26c3e041-a07f-4961-828f-688ca2e5d5a0 | 28 of 96
# Generating sketch gallery for participant: 2972-3a56f835-d354-4cdf-80d4-8c914cac4e2f | 29 of 96
# Generating sketch gallery for participant: 2994-3ecb024f-d077-4f3a-82b1-7dc7a1e4c248 | 30 of 96
# Generating sketch gallery for participant: 3006-c31af4b2-8198-42ec-a1b8-99ad83fc262a | 31 of 96
# Generating sketch gallery for participant: 3044-9334cd27-acc2-4931-aa73-6df3908d48ae | 32 of 96
# Generating sketch gallery for participant: 3149-ac24226c-f996-4221-8935-279e162a5578 | 33 of 96
# Generating sketch gallery for participant: 3187-6fafe473-a97f-4c53-9f79-ca86a451d7d4 | 34 of 96
# Generating sketch gallery for participant: 3409-cdd9b599-cdcb-4ee3-a7c7-fc4dd4acbae8 | 35 of 96
# Generating sketch gallery for participant: 3514-7f623136-e25e-45ac-8780-74d6e0494dad | 36 of 96
# Generating sketch gallery for participant: 3540-0b86929e-b288-4851-a26b-a3a1e3d6c483 | 37 of 96
# Generating sketch gallery for participant: 3580-da6f2c7c-026e-4d3c-84be-cdf62517a433 | 38 of 96
# Generating sketch gallery for participant: 3602-b37ba36e-3863-4fa4-8b95-0ed11de2bd8c | 39 of 96
# Generating sketch gallery for participant: 3653-69255bfa-8a5e-48b9-b072-1cf1e2b30e37 | 40 of 96
# Generating sketch gallery for participant: 3697-35a5fa83-89b8-4b77-9610-4070b3e41091 | 41 of 96
# Generating sketch gallery for participant: 3704-d98140aa-8abd-4e9d-a738-4d890a774522 | 42 of 96
# Generating sketch gallery for participant: 4027-b4cfc265-758a-435c-a676-6593e8bb7dc5 | 43 of 96
# Generating sketch gallery for participant: 4260-53d68a3a-d96c-4788-9ee6-b2d8818897eb | 44 of 96
# Generating sketch gallery for participant: 4331-b8ab79c0-e069-49b8-991f-32dfee3a3c2b | 45 of 96
# Generating sketch gallery for participant: 4604-39893b2b-ebbe-4273-8054-e91532299ee4 | 46 of 96
# Generating sketch gallery for participant: 4613-407defcd-ca61-4962-8baf-0a5b78a963a3 | 47 of 96
# Generating sketch gallery for participant: 4631-80ba5f63-ba5d-4cdf-a40b-9365fb186eab | 48 of 96
# Generating sketch gallery for participant: 4711-41490451-93ee-43ff-b603-cd095a2bef92 | 49 of 96
# Generating sketch gallery for participant: 4823-b91a4917-9eff-4407-94a1-9b43f747651e | 50 of 96
# Generating sketch gallery for participant: 4832-80462d9f-6c58-4dc0-af8b-07f722a642ea | 51 of 96
# Generating sketch gallery for participant: 5164-9009bdb1-d100-4b8a-9016-69f6d0530c1f | 52 of 96
# Generating sketch gallery for participant: 5237-d4584d51-1264-4de3-b190-cc75c8f4dcfa | 53 of 96
# Generating sketch gallery for participant: 5371-bbf5f66c-4ddf-458f-ae8c-beadc9749f39 | 54 of 96
# Generating sketch gallery for participant: 5384-6e26a300-134d-4f60-b6a5-4270f6241518 | 55 of 96
# Generating sketch gallery for participant: 5509-33bfee8a-abb3-4678-a113-4b897b3d7c7a | 56 of 96
# Generating sketch gallery for participant: 5627-d5064291-ac7c-4819-a13d-28f256669aa3 | 57 of 96
# Generating sketch gallery for participant: 6076-da404f4b-8578-44c6-b49a-3578aeaacff5 | 58 of 96
# Generating sketch gallery for participant: 6374-3ede30f2-40bf-4ecd-bd03-a91f96fb3308 | 59 of 96
# Generating sketch gallery for participant: 6386-74559261-9bfc-4d11-8fd9-4a3aeef882af | 60 of 96
# Generating sketch gallery for participant: 6439-0c42d6c3-0561-4d2b-a198-a108d557b431 | 61 of 96
# Generating sketch gallery for participant: 6542-653303a8-04e0-478c-b7f8-f49621c009fd | 62 of 96
# Generating sketch gallery for participant: 6640-0235ee6b-2428-4ec2-a917-1c7ac947adee | 63 of 96
# Generating sketch gallery for participant: 6798-e2368661-080e-4a6d-a4af-8455795f74a3 | 64 of 96
# Generating sketch gallery for participant: 6846-05387701-60dd-4533-b4df-42cdb19d5627 | 65 of 96
# Generating sketch gallery for participant: 6847-ceb06121-56d6-4ae4-8129-a14a5e2c81ce | 66 of 96
# Generating sketch gallery for participant: 7182-f27e8ddc-4de2-4346-821d-32734337c1ee | 67 of 96
# Generating sketch gallery for participant: 7338-654fb26b-0253-47d2-9d0f-e2bc572420cf | 68 of 96
# Generating sketch gallery for participant: 7433-d902ab3a-622a-4f04-acaf-cd5d5b3b4365 | 69 of 96
# Generating sketch gallery for participant: 7480-3d07c25c-3033-49b3-aa50-2123a2fb8c34 | 70 of 96
# Generating sketch gallery for participant: 7544-e93f27c0-0e5d-418b-b235-3376574b8e06 | 71 of 96
# Generating sketch gallery for participant: 7666-0bfe6a5d-e5c9-46b8-920e-0abc17d9997a | 72 of 96
# Generating sketch gallery for participant: 7672-e304144f-2989-4897-b462-257a390419fe | 73 of 96
# Generating sketch gallery for participant: 7779-35a27f02-795c-4c0e-be7c-e84df60d9024 | 74 of 96
# Generating sketch gallery for participant: 8041-7dccbbed-c254-450e-a1ba-9d71fc9f2a41 | 75 of 96
# Generating sketch gallery for participant: 8081-01144ea4-3c58-484a-8122-f4e39da75b9f | 76 of 96
# Generating sketch gallery for participant: 8251-7b9192f9-e119-4c1d-8b94-20b6380a55f2 | 77 of 96
# Generating sketch gallery for participant: 8288-6f9238b7-b958-4186-b88f-5b86dcab2f96 | 78 of 96
# Generating sketch gallery for participant: 8314-c5f1d232-f1d5-48b2-b8ef-a40274666e98 | 79 of 96
# Generating sketch gallery for participant: 8443-efb42d93-fe58-4a60-89ea-d6853b31eb7d | 80 of 96
# Generating sketch gallery for participant: 8450-84086b6f-042d-418b-b43e-a30662d6ed77 | 81 of 96
# Generating sketch gallery for participant: 8640-7215bfc0-26ed-47e1-82a0-650372ad8511 | 82 of 96
# Generating sketch gallery for participant: 8664-6fd3ed4a-5e42-436b-b4e1-fa732c16694e | 83 of 96
# Generating sketch gallery for participant: 8683-5c9bd49e-74be-4c0c-9323-cd538c8569a9 | 84 of 96
# Generating sketch gallery for participant: 8824-5363798b-5398-4a77-b68a-f061dbcf4f33 | 85 of 96
# Generating sketch gallery for participant: 8968-86fcb2df-875f-4e88-82e3-3d66133a77aa | 86 of 96
# Generating sketch gallery for participant: 8989-db564164-2496-451f-a560-ea1d549c80aa | 87 of 96
# Generating sketch gallery for participant: 9161-cd185b45-6ee5-4132-833f-b6a0a318c589 | 88 of 96
# Generating sketch gallery for participant: 9352-c639ab0b-4b46-4d77-ac8e-524424318edd | 89 of 96
# Generating sketch gallery for participant: 9374-464ce83c-56e4-4b33-beb5-53f4e8c4b718 | 90 of 96
# Generating sketch gallery for participant: 9466-97bd3c10-a6f5-4049-aa84-366cf624365e | 91 of 96
# Generating sketch gallery for participant: 9566-e1109211-adc4-4149-a486-8d6103c8e3de | 92 of 96
# Generating sketch gallery for participant: 9759-fae6bedc-11f7-48df-a912-52ebc28c08a1 | 93 of 96
# Generating sketch gallery for participant: 9795-36515630-9319-4db4-bd48-259df2f40359 | 94 of 96
# Generating sketch gallery for participant: 9853-0d3ea1f6-6184-4a8e-82ba-7345bf84a921 | 95 of 96
# Generating sketch gallery for participant: 9866-c92f9963-4a1b-4e19-ae1c-ab73c1bbc44c | 96 of 96
# Done!
# Generating sketch gallery for participant: 0088-6c550b0e-1674-410b-b027-e9bdcdb0d905 | 1 of 96
# Generating sketch gallery for participant: 0260-ec8c77a0-b084-4598-88aa-7a76d245f1e8 | 2 of 96
# Generating sketch gallery for participant: 0318-4ca44be3-613f-40cc-a7f5-7e41b91b66a1 | 3 of 96
# Generating sketch gallery for participant: 0555-19d3deae-1faa-428f-971e-a9cbd2829f27 | 4 of 96
# Generating sketch gallery for participant: 0571-fecc84f9-8daf-4350-b6b7-56061947bcfa | 5 of 96
# Generating sketch gallery for participant: 0631-05f1b367-3ebd-4e92-8eda-22374acf3998 | 6 of 96
# Generating sketch gallery for participant: 0631-152b71ad-07bd-49f7-9efb-f3e2b45c7899 | 7 of 96
# Generating sketch gallery for participant: 0730-a148929c-b9e9-4a43-83ba-2d30beb93dc5 | 8 of 96
# Generating sketch gallery for participant: 0755-cb335818-ecf7-4181-bdec-ea12ad61c60b | 9 of 96
# Generating sketch gallery for participant: 0824-ed053cb6-5f26-4db4-b05a-874cb1b98d9e | 10 of 96
# Generating sketch gallery for participant: 0967-19adbbee-7508-4010-a2ce-7caf998263b6 | 11 of 96
# Generating sketch gallery for participant: 1019-0bb8e3b8-f26d-4809-9fe8-a7ce536a3799 | 12 of 96
# Generating sketch gallery for participant: 1204-1a7eebd7-8eb0-456e-abbf-c6dba29fefb2 | 13 of 96
# Generating sketch gallery for participant: 1236-ba6668b1-7309-48e0-9d42-1f59c7457c49 | 14 of 96
# Generating sketch gallery for participant: 1242-0b6b8ebd-4991-4cb6-b36f-aa7dc32fd305 | 15 of 96
# Generating sketch gallery for participant: 1300-8f7c1500-12e8-4bb5-a428-df03b65cc0e4 | 16 of 96
# Generating sketch gallery for participant: 1338-c7d3502b-9c20-4041-abab-841e3d3aa0ce | 17 of 96
# Generating sketch gallery for participant: 1550-dd85c02c-c8a8-49aa-9e78-e67b530575d1 | 18 of 96
# Generating sketch gallery for participant: 1718-fe48037c-c071-4a93-b200-9b72417b8a68 | 19 of 96
# Generating sketch gallery for participant: 1912-1fc270ad-ae0d-4098-825d-14fa7b9df8a9 | 20 of 96
# Generating sketch gallery for participant: 1934-5238f83e-526d-46d0-9791-51b11174e72c | 21 of 96
# Generating sketch gallery for participant: 1976-c5a3d0e3-d1a6-4824-9119-feeaa3880fc9 | 22 of 96
# Generating sketch gallery for participant: 2024-1c3195da-57bf-49fa-b3e8-bee2b759fc66 | 23 of 96
# Generating sketch gallery for participant: 2062-98919c3a-90a3-4fb3-a97c-0b3094c4c9ef | 24 of 96
# Generating sketch gallery for participant: 2101-7a47fc6e-8e8b-4c0e-9285-b9eb5874ef63 | 25 of 96
# Generating sketch gallery for participant: 2108-3860b9b0-aeb6-4ee2-be8e-0c8998c6d70d | 26 of 96
# Generating sketch gallery for participant: 2214-2bf7af75-7477-44e8-b10a-3744f4e23dec | 27 of 96
# Generating sketch gallery for participant: 2252-22bce314-cc55-4897-963a-8f2340beeacb | 28 of 96
# Generating sketch gallery for participant: 2452-a27d0c10-9cf0-4799-a3ff-beccb051fc72 | 29 of 96
# Generating sketch gallery for participant: 2539-755d04d6-9de5-4cf5-a48a-cc23089edffe | 30 of 96
# Generating sketch gallery for participant: 2541-83adaed5-316d-4c35-99c4-dbff30003eed | 31 of 96
# Generating sketch gallery for participant: 2688-aac13ebb-1ee3-4cf7-a33c-d92f74e6324c | 32 of 96
# Generating sketch gallery for participant: 2742-2c815a4e-797c-4487-ade0-0789808ed317 | 33 of 96
# Generating sketch gallery for participant: 2779-e0ad3d81-1697-47b5-8b28-b6c095f71da4 | 34 of 96
# Generating sketch gallery for participant: 2895-0ad20737-6dca-4dde-82a7-dfc7bc4d8ead | 35 of 96
# Generating sketch gallery for participant: 3080-fc28b8bf-b4d1-4d3c-a6c7-8bc5409b45b6 | 36 of 96
# Generating sketch gallery for participant: 3148-ce87562e-a84b-41f2-81bf-187523358af0 | 37 of 96
# Generating sketch gallery for participant: 3167-4e7bc229-2d45-4c21-86cc-1c92d3940801 | 38 of 96
# Generating sketch gallery for participant: 3195-e4d90d9d-f375-4718-97a3-4782916f86cf | 39 of 96
# Generating sketch gallery for participant: 3372-27af025d-0d30-4c95-9441-9466aa8f0fc4 | 40 of 96
# Generating sketch gallery for participant: 3383-e83fc6ba-a630-4456-91b8-b93845d83d58 | 41 of 96
# Generating sketch gallery for participant: 3554-7e930a27-4272-40a2-a4d8-c269a7a9b9c2 | 42 of 96
# Generating sketch gallery for participant: 3589-7d28c8c8-06b6-430d-b84c-c4548653e8f2 | 43 of 96
# Generating sketch gallery for participant: 4060-1264f0a9-48c0-4e2c-83ce-ca2fa89e0dd1 | 44 of 96
# Generating sketch gallery for participant: 4120-ec3fff13-b670-49b1-9ca8-f352ef8465e8 | 45 of 96
# Generating sketch gallery for participant: 4133-c4f62541-1cef-49b9-8f08-a7af6e91b9af | 46 of 96
# Generating sketch gallery for participant: 4155-5bb7ae96-fd21-4078-b1ab-4cc26b824e11 | 47 of 96
# Generating sketch gallery for participant: 4310-2708b3a3-dec1-4b0f-be7c-61c15747d16b | 48 of 96
# Generating sketch gallery for participant: 4556-8eade920-4d50-46ca-8b94-16ca53e141ce | 49 of 96
# Generating sketch gallery for participant: 4603-a1b77f59-464b-461c-bae7-c2e2261fefa3 | 50 of 96
# Generating sketch gallery for participant: 4615-41a4b2d8-08b7-4d08-b841-45c2e92d5395 | 51 of 96
# Generating sketch gallery for participant: 4715-bafb0b6d-396c-4c03-96a8-ed487f4254ee | 52 of 96
# Generating sketch gallery for participant: 4790-878b4dba-8ffb-437d-8010-bdd6ddd7d5a1 | 53 of 96
# Generating sketch gallery for participant: 4995-7fd3e9e3-b2f0-4635-87d0-345f2d269073 | 54 of 96
# Generating sketch gallery for participant: 5096-670d80d0-4a8b-49b1-b6e2-892aec5f5d90 | 55 of 96
# Generating sketch gallery for participant: 5293-cd54197a-bb98-49f6-a184-be2cce76245a | 56 of 96
# Generating sketch gallery for participant: 5391-537cbf13-2161-4afd-905a-648f65a4eadb | 57 of 96
# Generating sketch gallery for participant: 5477-fad16080-317e-4a01-b593-9ae82182efa4 | 58 of 96
# Generating sketch gallery for participant: 5536-eaaf63f0-19d4-4690-994c-59a2adc9d468 | 59 of 96
# Generating sketch gallery for participant: 5618-d60c9ee6-6494-462a-ad00-e93c15105d4c | 60 of 96
# Generating sketch gallery for participant: 5695-1b66005d-cac6-4082-a55f-51adf0ee3033 | 61 of 96
# Generating sketch gallery for participant: 5701-fafdc767-5e4c-400c-ab71-015ba238ee35 | 62 of 96
# Generating sketch gallery for participant: 5962-e1f46e68-8ebe-49a5-8272-27dbc728224b | 63 of 96
# Generating sketch gallery for participant: 6252-a90d51a4-3fd1-4331-a638-3658e94e186a | 64 of 96
# Generating sketch gallery for participant: 6276-c3380cf2-e38a-473a-83e8-03f6b52e35ba | 65 of 96
# Generating sketch gallery for participant: 6662-3556306a-72ca-42cd-bc79-075d96a29ccc | 66 of 96
# Generating sketch gallery for participant: 6690-3503c5be-4d33-4856-ae5d-ea387462c894 | 67 of 96
# Generating sketch gallery for participant: 6921-9a7bc842-f257-4360-a8cb-e5289714b039 | 68 of 96
# Generating sketch gallery for participant: 7092-639010a8-023d-4df0-9ed9-f2157701b65e | 69 of 96
# Generating sketch gallery for participant: 7139-aa017962-7cad-4b08-bf3d-b3e0f81ca5c6 | 70 of 96
# Generating sketch gallery for participant: 7239-82275173-48ff-43ff-81ab-5513eec34a1a | 71 of 96
# Generating sketch gallery for participant: 7314-c28cbbba-fdce-4a56-aa9b-eb308b7437c8 | 72 of 96
# Generating sketch gallery for participant: 7425-e83b0bb8-29b9-4b26-bd54-84a71b955634 | 73 of 96
# Generating sketch gallery for participant: 7446-76165afa-93ac-439e-94a3-1ac6d262d1fe | 74 of 96
# Generating sketch gallery for participant: 7528-0df40860-01fa-410d-9b88-c4135cfbd9c7 | 75 of 96
# Generating sketch gallery for participant: 7546-6f3083bd-b056-4abd-8cdf-9cea29733456 | 76 of 96
# Generating sketch gallery for participant: 7559-02cafe3c-cabc-454e-b3ed-9f0dcbb7605a | 77 of 96
# Generating sketch gallery for participant: 7617-e9b703cd-c3cf-4d1d-8d83-f6297c701998 | 78 of 96
# Generating sketch gallery for participant: 7683-b4c938f3-0582-47e6-8258-38752b7588b7 | 79 of 96
# Generating sketch gallery for participant: 7699-e445344c-6d45-4d79-bf9b-b43b62fa8d47 | 80 of 96
# Generating sketch gallery for participant: 7701-5e5fcdef-8e86-49dd-889c-b62ed0e5a2f8 | 81 of 96
# Generating sketch gallery for participant: 7938-8c3838df-5479-4e1d-8b59-57a50a7d5479 | 82 of 96
# Generating sketch gallery for participant: 7996-6652369d-312d-40d0-849f-c447a8367e90 | 83 of 96
# Generating sketch gallery for participant: 8343-18fa3b50-c128-408d-b79e-f394ee03c0c8 | 84 of 96
# Generating sketch gallery for participant: 8720-2f784642-7439-493b-99e2-4483f968950a | 85 of 96
# Generating sketch gallery for participant: 8932-e2cae874-8031-4e89-8489-6d215c7842bb | 86 of 96
# Generating sketch gallery for participant: 8964-5824a96d-1a0d-4b12-982c-697141bad7c4 | 87 of 96
# Generating sketch gallery for participant: 9178-b22d407b-9f71-4488-8b49-332f960e6be2 | 88 of 96
# Generating sketch gallery for participant: 9427-5f6ee77b-1a80-488f-bfcd-16642d048c50 | 89 of 96
# Generating sketch gallery for participant: 9664-3ab337d8-c584-487d-aacd-19ea3971f5f7 | 90 of 96
# Generating sketch gallery for participant: 9692-fcf9d426-d820-41be-a58a-a48cf1265894 | 91 of 96
# Generating sketch gallery for participant: 9739-5b6ad25f-7e8a-4193-ba28-fd8a413a8165 | 92 of 96
# Generating sketch gallery for participant: 9742-e2d3becb-01f9-4fed-a41b-60228354ed60 | 93 of 96
# Generating sketch gallery for participant: 9759-e1e2f924-f8f9-47e3-82ff-a66447d609aa | 94 of 96
# Generating sketch gallery for participant: 9897-75e7c370-9d40-40e8-9557-40f3b4d85a59 | 95 of 96
# Generating sketch gallery for participant: 9987-897ddc12-2ece-4a79-9367-112f1afb05ed | 96 of 96
# Done!
# Generating sketch gallery for participant: 0000-62e496cc-35dc-4391-ac09-434fd04a48b4 | 1 of 96
# Generating sketch gallery for participant: 0229-bf914407-46cd-48cb-b14d-5ca326a0d022 | 2 of 96
# Generating sketch gallery for participant: 0629-4c182b64-80eb-4859-8f38-9f05d4836b00 | 3 of 96
# Generating sketch gallery for participant: 0659-73b274ba-5b7c-40f3-a0da-8c6676e320bc | 4 of 96
# Generating sketch gallery for participant: 0711-d3a3042f-2421-4029-b1ef-39c40bf28c4a | 5 of 96
# Generating sketch gallery for participant: 0954-82c7800b-4edd-4048-8d7a-db61f5cd86e6 | 6 of 96
# Generating sketch gallery for participant: 1015-b439b2d4-c24c-446c-9ced-3f94bd221ab4 | 7 of 96
# Generating sketch gallery for participant: 1045-a7997465-b1bc-4767-aa36-4bd31f418b9c | 8 of 96
# Generating sketch gallery for participant: 1134-6d1688c9-b1ed-4400-93d5-8ba9a22e4c48 | 9 of 96
# Generating sketch gallery for participant: 1289-2c5b500b-fe2e-4658-a458-87b1c4835e59 | 10 of 96
# Generating sketch gallery for participant: 1309-716f257b-1174-4b19-b5ff-e241fb29850b | 11 of 96
# Generating sketch gallery for participant: 1492-ce495226-5e29-4695-8205-5f9cd2eaf703 | 12 of 96
# Generating sketch gallery for participant: 1538-7e15bcb2-ef62-4079-b95c-83533d8fafd3 | 13 of 96
# Generating sketch gallery for participant: 1655-01f57de1-eaa5-4cca-ace9-48d4d8e64497 | 14 of 96
# Generating sketch gallery for participant: 1785-00927e08-1b9d-4e26-92e5-1a697cfd8a05 | 15 of 96
# Generating sketch gallery for participant: 1830-5950f3c5-e316-49ad-adcf-4309b1ba98bf | 16 of 96
# Generating sketch gallery for participant: 1915-9e8f0fad-986a-4704-926b-dbc94219e753 | 17 of 96
# Generating sketch gallery for participant: 1919-afb406cf-54d9-4546-8f46-891fb7ced0c8 | 18 of 96
# Generating sketch gallery for participant: 1936-5fc2af1e-3157-4d92-bb9f-43f2f8bb6b53 | 19 of 96
# Generating sketch gallery for participant: 2067-0e42589f-5641-4f2d-9f4e-b3967b2c602e | 20 of 96
# Generating sketch gallery for participant: 2379-11ba309c-4def-410d-ab5a-1715214f3e7c | 21 of 96
# Generating sketch gallery for participant: 2385-2a75f5a3-1717-4409-9f5d-862fbf6f9192 | 22 of 96
# Generating sketch gallery for participant: 2446-34386809-9ce3-4539-bac1-d1bf641f9a5a | 23 of 96
# Generating sketch gallery for participant: 2531-404bf920-d953-4fec-9b92-de100eff413f | 24 of 96
# Generating sketch gallery for participant: 2573-082d0abd-180a-4dd0-850e-cc28e53cc273 | 25 of 96
# Generating sketch gallery for participant: 2606-68bc4276-869a-46d4-9b91-90489380df42 | 26 of 96
# Generating sketch gallery for participant: 2837-edd03006-111f-49ab-98ad-c3cf650e6d12 | 27 of 96
# Generating sketch gallery for participant: 3027-e13313b4-d340-4ff3-8e28-47a876954210 | 28 of 96
# Generating sketch gallery for participant: 3099-ad32cec9-3886-484b-bd98-097190c435ab | 29 of 96
# Generating sketch gallery for participant: 3198-db908e2a-8fba-460b-b240-3905a0de18bd | 30 of 96
# Generating sketch gallery for participant: 3279-eff711d2-586e-4600-8feb-3c9f8e2acdfb | 31 of 96
# Generating sketch gallery for participant: 3497-ec6b114d-9075-43b4-b3b4-54a9cb3c41d2 | 32 of 96
# Generating sketch gallery for participant: 3553-2579099a-1e34-4953-9cfd-8887ab9ff70a | 33 of 96
# Generating sketch gallery for participant: 3653-d4d4d528-e0dc-4867-8d73-19b9ce8639a1 | 34 of 96
# Generating sketch gallery for participant: 3680-82bb3b22-35fa-47cc-85eb-e5d33652ce1b | 35 of 96
# Generating sketch gallery for participant: 3722-68f93e0a-7e89-4c03-8c18-8a6781133929 | 36 of 96
# Generating sketch gallery for participant: 3823-3c285c18-de54-48eb-acf3-87d6c91a2acb | 37 of 96
# Generating sketch gallery for participant: 3944-05f27692-3655-4524-94f2-095f4e47fefc | 38 of 96
# Generating sketch gallery for participant: 3994-5d14d9c4-311a-4cd8-b251-d137d7c9da74 | 39 of 96
# Generating sketch gallery for participant: 4085-99f4f147-ecef-4e0d-8a3d-dcf140655d2c | 40 of 96
# Generating sketch gallery for participant: 4114-1e3693e3-76f2-42ed-9652-ad412415bbab | 41 of 96
# Generating sketch gallery for participant: 4348-a1a8acc6-2f2c-4573-b30b-6043dfbdf635 | 42 of 96
# Generating sketch gallery for participant: 4352-695176bb-ff03-40e3-a705-59302938023a | 43 of 96
# Generating sketch gallery for participant: 4373-f281bc73-a5f0-4091-886c-fb517beeb2af | 44 of 96
# Generating sketch gallery for participant: 4483-253d92c9-b8a3-42d0-bc8c-c78a591a5609 | 45 of 96
# Generating sketch gallery for participant: 4487-9d6deb5e-c902-4339-b38f-2fb927557705 | 46 of 96
# Generating sketch gallery for participant: 4544-97316549-74af-471b-988d-e929ce515e6f | 47 of 96
# Generating sketch gallery for participant: 4580-0a00b138-f6ed-4c16-9d21-97e242fb551c | 48 of 96
# Generating sketch gallery for participant: 4649-3629f774-b199-45ca-bfb3-7cdf9b435f0c | 49 of 96
# Generating sketch gallery for participant: 5026-61a55061-dffb-4169-bd1e-0e553a6c2176 | 50 of 96
# Generating sketch gallery for participant: 5108-027e7608-8f9e-4df7-acad-808a3101e426 | 51 of 96
# Generating sketch gallery for participant: 5130-8de8c2b0-ed9d-4a2b-812c-6c0188db5082 | 52 of 96
# Generating sketch gallery for participant: 5138-183ad95d-2552-447c-92f2-b572c0231812 | 53 of 96
# Generating sketch gallery for participant: 5155-7782a65f-4174-47d3-a0f2-2095841e5d2e | 54 of 96
# Generating sketch gallery for participant: 5401-984b9be5-e486-4b9a-93dd-5d79b8aac908 | 55 of 96
# Generating sketch gallery for participant: 5432-2dd7733a-0cfa-4b90-885e-d0a7f9797e37 | 56 of 96
# Generating sketch gallery for participant: 5539-d651fd63-8041-465f-939c-30acdb44d90c | 57 of 96
# Generating sketch gallery for participant: 5723-2bea42f8-04c0-49bb-9aeb-8163357a4a51 | 58 of 96
# Generating sketch gallery for participant: 5746-dd897e2a-8af7-43b3-9d7c-0586eb396d32 | 59 of 96
# Generating sketch gallery for participant: 5858-03751bd9-d1f1-476b-8aea-666adac7405c | 60 of 96
# Generating sketch gallery for participant: 5921-c7756a91-d3fb-4ea9-af9f-7d43982056f1 | 61 of 96
# Generating sketch gallery for participant: 5929-bf51df99-6ded-471f-9c0e-466f86c561f8 | 62 of 96
# Generating sketch gallery for participant: 5942-15df2a49-f232-499a-896f-44dc87c15697 | 63 of 96
# Generating sketch gallery for participant: 5997-6f335be2-a8d5-499e-b717-7848b8c34907 | 64 of 96
# Generating sketch gallery for participant: 6153-193521ea-2b36-469a-af08-4fb7051c41dd | 65 of 96
# Generating sketch gallery for participant: 6177-5ca91079-ad3e-4149-91f2-31a8a6387b1e | 66 of 96
# Generating sketch gallery for participant: 6282-67436a4e-dd24-4a4b-8bdb-253b0b820b13 | 67 of 96
# Generating sketch gallery for participant: 6339-f84169d9-d0d3-4040-b4ad-a4dfa9d4443c | 68 of 96
# Generating sketch gallery for participant: 6545-3c30d7f9-ff3f-4e1b-a4c1-66e018d4a74d | 69 of 96
# Generating sketch gallery for participant: 6800-375a11e2-e330-4726-9bd5-13b9550b054a | 70 of 96
# Generating sketch gallery for participant: 6997-9c4ca38c-c355-4783-88fd-110cb7a23737 | 71 of 96
# Generating sketch gallery for participant: 7080-13cf79fc-5f6b-4312-8db1-d38012bdd1c3 | 72 of 96
# Generating sketch gallery for participant: 7163-0db0815b-41d9-47fa-a8ed-3745bc0f8caa | 73 of 96
# Generating sketch gallery for participant: 7330-b54f3bce-12dd-45da-a1ac-586b0b0afb96 | 74 of 96
# Generating sketch gallery for participant: 7471-962d05ff-6343-4772-bce1-9dbedd1fcbc5 | 75 of 96
# Generating sketch gallery for participant: 7552-8613d633-2330-4b92-ba24-63a56118f936 | 76 of 96
# Generating sketch gallery for participant: 7783-3d848605-e5b3-4297-8ea5-f4b9bf3b65f4 | 77 of 96
# Generating sketch gallery for participant: 7787-05abbd26-4542-4072-8dbc-0df01274383d | 78 of 96
# Generating sketch gallery for participant: 7867-d98e6cf6-6d96-4566-92f5-b20ad612c787 | 79 of 96
# Generating sketch gallery for participant: 7894-a89939d9-79b1-4080-b6b3-86eeb7415316 | 80 of 96
# Generating sketch gallery for participant: 7936-3485b3d2-cce9-49b4-bf45-728aa8158fd7 | 81 of 96
# Generating sketch gallery for participant: 8120-8e953952-faba-472c-b7fa-26f02bb7efa4 | 82 of 96
# Generating sketch gallery for participant: 8481-08717c4b-b652-4e96-b6f2-4341d04d800f | 83 of 96
# Generating sketch gallery for participant: 8767-ffaf5435-f697-4940-a28b-b2ce5b742092 | 84 of 96
# Generating sketch gallery for participant: 8822-7ef91826-9dc6-49de-8b57-412d7a07dcbe | 85 of 96
# Generating sketch gallery for participant: 8848-acbed75e-f57d-4724-98cb-14099fa16aa7 | 86 of 96
# Generating sketch gallery for participant: 9040-371d6693-e587-4af7-8bd2-9f0ee7a37205 | 87 of 96
# Generating sketch gallery for participant: 9076-78be8867-49b5-4f4f-b9d3-f1cd9c96e315 | 88 of 96
# Generating sketch gallery for participant: 9153-846487a5-b9f6-4319-b9b4-97fdf2ac01c7 | 89 of 96
# Generating sketch gallery for participant: 9267-69f2b975-0307-4774-8b7b-b8ed30597ebf | 90 of 96
# Generating sketch gallery for participant: 9285-1a90fa46-6847-49f8-8e4d-5dc1588d2408 | 91 of 96
# Generating sketch gallery for participant: 9473-800ff654-3a16-48c0-a3c8-5df83d527ab4 | 92 of 96
# Generating sketch gallery for participant: 9564-42c23c46-bc60-411d-a5b8-b5d8330f7b34 | 93 of 96
# Generating sketch gallery for participant: 9669-0b13c0c8-09da-4d2a-b912-eee814b8b072 | 94 of 96
# Generating sketch gallery for participant: 9727-3d9acb1f-5ebb-4053-a1ce-5e89b0c80308 | 95 of 96
# Generating sketch gallery for participant: 9760-ea6d2940-aa18-48bd-be41-d32a72c891cd | 96 of 96
# Done!

# %% [markdown]
# ### render out sketches for feature extraction

# %%
sketch_df = pd.read_csv(os.path.join(csv_dir, 'photodraw2x2_sketch_data.csv'))

importlib.reload(utils)

utils.render_images(sketch_df, data = 'pngData',
                    metadata = ['gameID', 'trialNum', 'condition','category','imageURL', 'goal'],
                    out_dir = os.path.join(sketch_dir, 'photodraw2x2'))
# Out:
# Done rendering 12288 images to F:\photodraw\sketches\photodraw2x2.

# %% [markdown]
# ### Finally, reload sketch data and add fc6 feature predictions

# %% [markdown]
# `python extract_features.py --data=/photodraw/sketches/photodraw2x2 --layer_ind=5 --data_type=sketch --spatial_avg=True --channel_norm=False --out_dir=/photodraw/features/ --experiment_flag=photodraw2x2`
#
# `python extract_features.py --data=/photodraw/stimuli/photodraw32_stims_copy --layer_ind=5 --data_type=image --spatial_avg=True --channel_norm=False --out_dir=/photodraw/features/ --experiment_flag=photodraw2x2_stims`
#
# `python extract_features.py --data=/home/AD/juy003/photodraw/sketches/photodraw2x2 --layer_ind=5 --data_type=sketch --spatial_avg=True --channel_norm=False --out_dir=/home/AD/juy003/photodraw/features --experiment_flag=photodraw2x2`

# %%
# %%time
sketch_df = pd.read_csv(os.path.join(csv_dir, 'photodraw2x2_sketch_data.csv'))

M_fc6 = pd.read_csv(os.path.join(feature_dir, f'METADATA_photodraw2x2_sketch.csv'))
F_fc6 = np.load(os.path.join(feature_dir, f'FEATURES_FC6_photodraw2x2_sketch.npy'))

# sort sketches into same format as fc6 featuresb
sketch_df['trialNum'] = pd.to_numeric(sketch_df.trialNum, errors='coerce')
sketch_df = sketch_df.sort_values(by=['gameID', 'trialNum', 'condition', 'category', 'imageURL', 'goal']).reset_index(drop=True)

# parse M_fc6 into same format as sketch_df 
M_fc6[['gameID', 'trialNum', 'condition', 'category']] = M_fc6.image_id.str.split('_', 3, expand = True)
M_fc6[['category', 'goal']] = M_fc6.category.str.rsplit('_', 1, expand = True)
M_fc6.loc[M_fc6.condition != 'text', 'imageURL'] = M_fc6.loc[M_fc6.condition != 'text', 'category']\
                                                .str.rsplit('_', 2, expand = True).iloc[:,1:3].agg('_'.join, axis = 1)
M_fc6.loc[M_fc6.condition == 'text', 'imageURL'] = M_fc6.loc[M_fc6.condition == 'text', 'category']\
                                                .str.rsplit('_', 1, expand = True).iloc[:,1]

M_fc6.loc[M_fc6.condition != 'text', 'category'] = M_fc6.loc[M_fc6.condition != 'text', 'category']\
                                                .str.rsplit('_', 2, expand = True).iloc[:,0]
M_fc6.loc[M_fc6.condition == 'text', 'category'] = M_fc6.loc[M_fc6.condition == 'text', 'category']\
                                                .str.rsplit('_', 1, expand = True).iloc[:,0]

# put M_fc6 in the same order as sketch_df
M_fc6['trialNum'] = pd.to_numeric(M_fc6.trialNum, errors='coerce')
M_fc6 = M_fc6.sort_values(by=['gameID', 'trialNum', 'condition', 'category', 'imageURL', 'goal']).reset_index(drop=True)

# make sure the dataframes and numpy arrays are aligned
a = ['_'.join(str(x) for x in lis) for lis in M_fc6[['gameID', 'trialNum', 'condition',  \
                                                        'category', 'imageURL', 'goal']].values]
b = ['_'.join(str(x) for x in lis) for lis in sketch_df[['gameID', 'trialNum', 'condition', \
                                                        'category', 'imageURL', 'goal']].values]

assert a == b

# assert that the a and b map uniquely between M_fc6 and sketch_df to ensure everything is well aligned
assert len(M_fc6) == len(sketch_df) == len(set(a)) == len(set(b))

# reindex feature data and normalize it a bit 
img_data = F_fc6[M_fc6.feature_ind.values]
img_data = img_data - img_data.mean(axis = 0)

# add logistic regression predictions and probabilities to sketch dataframe for fc6 data
prob_dict, pred_dict = compute_class_predictions(img_data, sketch_df.category.values)
sketch_df['prob_true_predict_fc6'] = sketch_df.index.map(prob_dict)
sketch_df['true_predict_fc6'] = sketch_df.index.map(pred_dict)
sketch_df['prob_true_predict_fc6_logodds'] = sketch_df.prob_true_predict_fc6.apply(lambda x: np.log(x) - np.log(1-x))

# add feature indices to sketch df for future ease of access
sketch_df['feature_ind'] = M_fc6.feature_ind.values

# save data out to csv
sketch_df.to_csv(os.path.join(csv_dir, 'photodraw2x2_sketch_data.csv'), index = False)
# Out:
# Wall time: 11min 10s

# %% [markdown]
# ### All done!
#
# To summarize the pipeline:
# - get data from mongo and clean it up
# - make image and gallery directories
# - run both instance and category feature extraction
# - get classification scores
